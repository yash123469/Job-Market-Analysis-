# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\sange\OneDrive\Attachments\Desktop\Attachments\Desktop\Job Market Analysis project\job market analysis project.csv")

# %%
df
# Out:
#       ID                                          Job_Title  \
# 0      0                                     Data Scientist
# 1      1                          Healthcare Data Scientist
# 2      2                                     Data Scientist
# 3      3                                     Data Scientist
# 4      4                                     Data Scientist
# ..   ...                                                ...
# 737  950           Sr Scientist, Immuno-Oncology - Oncology
# 738  951                               Senior Data Engineer
# 739  952  Project Scientist - Auton Lab, Robotics Institute
# 740  953                               Data Science Manager
# 741  955          Research Scientist – Security and Privacy
#
#                  Salary_Estimate  FIELD4  Rating  \
# 0     $53K-$91K (Glassdoor est.)     NaN     3.8
# 1    $63K-$112K (Glassdoor est.)     NaN     3.4
# 2     $80K-$90K (Glassdoor est.)     NaN     4.8
# ...

# %%
df.shape
# Out:
# (742, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  742 non-null    int64
#  1   Job_Title           742 non-null    object
#  2   Salary_Estimate     742 non-null    object
#  3   FIELD4              0 non-null      float64
#  4   Rating              742 non-null    float64
#  5   Company_Name        742 non-null    object
#  6   Location            742 non-null    object
#  7   Headquarters        742 non-null    object
#  8   Size                742 non-null    object
#  9   Founded             742 non-null    int64
#  10  Type_of_ownership   742 non-null    object
#  11  Industry            742 non-null    object
#  12  Sector              742 non-null    object
#  13  Revenue             742 non-null    object
#  14  Competitors         742 non-null    object
# ...

# %%
df.describe()
# Out:
#                ID  FIELD4      Rating      Founded      Hourly  \
# count  742.000000     0.0  742.000000   742.000000  742.000000
# mean   469.129380     NaN    3.618868  1837.154987    0.032345
# std    279.793117     NaN    0.801210   497.183763    0.177034
# min      0.000000     NaN   -1.000000    -1.000000    0.000000
# 25%    221.500000     NaN    3.300000  1939.000000    0.000000
# 50%    472.500000     NaN    3.700000  1988.000000    0.000000
# 75%    707.750000     NaN    4.000000  2007.000000    0.000000
# max    955.000000     NaN    5.000000  2019.000000    1.000000
#
#        Employer_provided  Lower_Salary  Upper_Salary  Avg_SalaryK         Age  \
# count         742.000000    742.000000    742.000000   742.000000  742.000000
# mean            0.022911     74.754717    128.214286   101.484501   47.524259
# std             0.149721     30.945892     45.128650    37.482449   53.839080
# min             0.000000     15.000000     16.000000    15.500000   -1.000000
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Job_Title', 'Salary_Estimate', 'FIELD4', 'Rating',
#        'Company_Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type_of_ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Employer_provided', 'Lower_Salary', 'Upper_Salary',
#        'Avg_SalaryK', 'company_txt', 'Job_Location', 'Age', 'Python', 'spark',
#        'aws', 'excel', 'sql_', 'sas', 'keras', 'pytorch', 'scikit', 'tensor',
#        'hadoop', 'tableau', 'bi', 'flink', 'mongo', 'google_an',
#        'job_title_sim', 'seniority_by_title', 'Degree'],
#       dtype='object')

# %%
print(df.shape[1])
# Out:
# 41

# %%
df.dtypes
# Out:
# ID                      int64
# Job_Title              object
# Salary_Estimate        object
# FIELD4                float64
# Rating                float64
# Company_Name           object
# Location               object
# Headquarters           object
# Size                   object
# Founded                 int64
# Type_of_ownership      object
# Industry               object
# Sector                 object
# Revenue                object
# Competitors            object
# Hourly                  int64
# Employer_provided       int64
# Lower_Salary            int64
# Upper_Salary            int64
# Avg_SalaryK           float64
# company_txt            object
# Job_Location           object
# Age                     int64
# Python                  int64
# spark                   int64
# aws                     int64
# excel                   int64
# sql_                    int64
# sas                     int64
# keras                   int64
# pytorch                 int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ID                      0
# Job_Title               0
# Salary_Estimate         0
# FIELD4                742
# Rating                  0
# Company_Name            0
# Location                0
# Headquarters            0
# Size                    0
# Founded                 0
# Type_of_ownership       0
# Industry                0
# Sector                  0
# Revenue                 0
# Competitors             0
# Hourly                  0
# Employer_provided       0
# Lower_Salary            0
# Upper_Salary            0
# Avg_SalaryK             0
# company_txt             0
# Job_Location            0
# Age                     0
# Python                  0
# spark                   0
# aws                     0
# excel                   0
# sql_                    0
# sas                     0
# keras                   0
# pytorch                 0
# scikit                  0
# tensor                  0
# hadoop                  0
# tableau                 0
# ...

# %%
newdf = df.dropna(axis=1)
newdf
# Out:
#       ID                                          Job_Title  \
# 0      0                                     Data Scientist
# 1      1                          Healthcare Data Scientist
# 2      2                                     Data Scientist
# 3      3                                     Data Scientist
# 4      4                                     Data Scientist
# ..   ...                                                ...
# 737  950           Sr Scientist, Immuno-Oncology - Oncology
# 738  951                               Senior Data Engineer
# 739  952  Project Scientist - Auton Lab, Robotics Institute
# 740  953                               Data Science Manager
# 741  955          Research Scientist – Security and Privacy
#
#                  Salary_Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', 'Job_Title', 'Salary_Estimate', 'Rating', 'Company_Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type_of_ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'Hourly',
#        'Employer_provided', 'Lower_Salary', 'Upper_Salary', 'Avg_SalaryK',
#        'company_txt', 'Job_Location', 'Age', 'Python', 'spark', 'aws', 'excel',
#        'sql_', 'sas', 'keras', 'pytorch', 'scikit', 'tensor', 'hadoop',
#        'tableau', 'bi', 'flink', 'mongo', 'google_an', 'job_title_sim',
#        'seniority_by_title', 'Degree'],
#       dtype='object')

# %%
print(newdf.shape[1])
# Out:
# 41

# %%
df['Company_Name'] = df['Company_Name'].str.split('\n').str[0]
df
# Out:
#       ID                                          Job_Title  \
# 0      0                                     Data Scientist
# 1      1                          Healthcare Data Scientist
# 2      2                                     Data Scientist
# 3      3                                     Data Scientist
# 4      4                                     Data Scientist
# ..   ...                                                ...
# 737  950           Sr Scientist, Immuno-Oncology - Oncology
# 738  951                               Senior Data Engineer
# 739  952  Project Scientist - Auton Lab, Robotics Institute
# 740  953                               Data Science Manager
# 741  955          Research Scientist – Security and Privacy
#
#                  Salary_Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# ...

# %%
df
# Out:
#       ID                                          Job_Title  \
# 0      0                                     Data Scientist
# 1      1                          Healthcare Data Scientist
# 2      2                                     Data Scientist
# 3      3                                     Data Scientist
# 4      4                                     Data Scientist
# ..   ...                                                ...
# 737  950           Sr Scientist, Immuno-Oncology - Oncology
# 738  951                               Senior Data Engineer
# 739  952  Project Scientist - Auton Lab, Robotics Institute
# 740  953                               Data Science Manager
# 741  955          Research Scientist – Security and Privacy
#
#                  Salary_Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Job_Title', 'Salary_Estimate', 'Rating', 'Company_Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type_of_ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'Hourly',
#        'Employer_provided', 'Lower_Salary', 'Upper_Salary', 'Avg_SalaryK',
#        'company_txt', 'Job_Location', 'Age', 'pytorch', 'scikit', 'tensor',
#        'hadoop', 'job_title_sim', 'seniority_by_title', 'Degree', 'skills'],
#       dtype='object')

# %%
df
# Out:
#       ID                                          Job_Title  \
# 0      0                                     Data Scientist
# 1      1                          Healthcare Data Scientist
# 2      2                                     Data Scientist
# 3      3                                     Data Scientist
# 4      4                                     Data Scientist
# ..   ...                                                ...
# 737  950           Sr Scientist, Immuno-Oncology - Oncology
# 738  951                               Senior Data Engineer
# 739  952  Project Scientist - Auton Lab, Robotics Institute
# 740  953                               Data Science Manager
# 741  955          Research Scientist – Security and Privacy
#
#                  Salary_Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Job_Title', 'Salary_Estimate', 'Rating', 'Company_Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Type_of_ownership',
#        'Industry', 'Sector', 'Revenue', 'Competitors', 'Hourly',
#        'Employer_provided', 'Lower_Salary', 'Upper_Salary', 'Avg_SalaryK',
#        'company_txt', 'Job_Location', 'Age', 'job_title_sim',
#        'seniority_by_title', 'Degree'],
#       dtype='object')

# %%
df.shape
# Out:
# (742, 26)

# %%
df.isnull().sum()
# Out:
# ID                    0
# Job_Title             0
# Salary_Estimate       0
# Rating                0
# Company_Name          0
# Location              0
# Headquarters          0
# Size                  0
# Founded               0
# Type_of_ownership     0
# Industry              0
# Sector                0
# Revenue               0
# Competitors           0
# Hourly                0
# Employer_provided     0
# Lower_Salary          0
# Upper_Salary          0
# Avg_SalaryK           0
# company_txt           0
# Job_Location          0
# Age                   0
# Python                0
# spark                 0
# aws                   0
# excel                 0
# sql_                  0
# sas                   0
# keras                 0
# pytorch               0
# scikit                0
# tensor                0
# hadoop                0
# tableau               0
# bi                    0
# flink                 0
# mongo                 0
# google_an             0
# ...

# %%
df.to_csv('cleaned_job_market.csv', index=False)
df
# Out:
#       ID                                          Job_Title  \
# 0      0                                     Data Scientist
# 1      1                          Healthcare Data Scientist
# 2      2                                     Data Scientist
# 3      3                                     Data Scientist
# 4      4                                     Data Scientist
# ..   ...                                                ...
# 737  950           Sr Scientist, Immuno-Oncology - Oncology
# 738  951                               Senior Data Engineer
# 739  952  Project Scientist - Auton Lab, Robotics Institute
# 740  953                               Data Science Manager
# 741  955          Research Scientist – Security and Privacy
#
#                  Salary_Estimate  Rating  \
# 0     $53K-$91K (Glassdoor est.)     3.8
# 1    $63K-$112K (Glassdoor est.)     3.4
# 2     $80K-$90K (Glassdoor est.)     4.8
# 3     $56K-$97K (Glassdoor est.)     3.8
# ...

# %%
df = pd.read_csv(r"C:\Users\sange\Downloads\job_market_analysis.csv")

# %%
df
# Out:
#        ID                                          Job_Title  Rating  \
# 0       1                                     Data Scientist     3.8
# 1       1                                     Data Scientist     3.8
# 2       1                                     Data Scientist     3.8
# 3       1                                     Data Scientist     3.8
# 4       1                                     Data Scientist     3.8
# ...   ...                                                ...     ...
# 2147  952                               Senior Data Engineer     4.4
# 2148  952                               Senior Data Engineer     4.4
# 2149  953  Project Scientist - Auton Lab, Robotics Institute     2.6
# 2150  954                               Data Science Manager     3.2
# 2151  956          Research Scientist – Security and Privacy     3.6
#
#                         Company_Name         Location       Headquarters  \
# ...
